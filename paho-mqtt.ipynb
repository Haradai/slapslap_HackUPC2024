# %%
import paho.mqtt.client as mqtt

# The callback for when the client receives a CONNACK response from the server.
def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    # Subscribing in on_connect() means that if we lose the connection and
    # reconnect then subscriptions will be renewed.
    client.subscribe("/Player1/Piezo1")
    

# The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
    
    print(msg.topic+" "+str(msg.payload))

mqttc = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
mqttc.on_connect = on_connect
mqttc.on_message = on_message

mqttc.connect("192.168.150.81", 1883, 60)

# Blocking call that processes network traffic, dispatches callbacks and
# handles reconnecting.
# Other loop*() functions are available that give a threaded interface and a
# manual interface.
mqttc.loop_forever()
# Out:
# Connected with result code Success
# /Player1/Piezo1 b'539'
# /Player1/Piezo1 b'0'
# /Player1/Piezo1 b'111'
# /Player1/Piezo1 b'63'
# /Player1/Piezo1 b'11'
# /Player1/Piezo1 b'48'
# /Player1/Piezo1 b'179'
# /Player1/Piezo1 b'309'
# /Player1/Piezo1 b'352'
# /Player1/Piezo1 b'397'
# /Player1/Piezo1 b'445'
# /Player1/Piezo1 b'558'
# /Player1/Piezo1 b'550'
# /Player1/Piezo1 b'694'
# /Player1/Piezo1 b'704'
# /Player1/Piezo1 b'736'
# /Player1/Piezo1 b'825'
# /Player1/Piezo1 b'862'
# /Player1/Piezo1 b'861'
# /Player1/Piezo1 b'854'
# /Player1/Piezo1 b'822'
# /Player1/Piezo1 b'943'
# /Player1/Piezo1 b'974'
# /Player1/Piezo1 b'959'
# /Player1/Piezo1 b'965'
# /Player1/Piezo1 b'980'
# /Player1/Piezo1 b'1015'
# /Player1/Piezo1 b'1031'
# /Player1/Piezo1 b'1075'
# /Player1/Piezo1 b'1042'
# /Player1/Piezo1 b'1066'
# /Player1/Piezo1 b'1103'
# /Player1/Piezo1 b'1099'
# /Player1/Piezo1 b'1197'
# /Player1/Piezo1 b'1123'
# /Player1/Piezo1 b'1139'
# /Player1/Piezo1 b'1117'
# /Player1/Piezo1 b'1136'
# /Player1/Piezo1 b'1095'
# /Player1/Piezo1 b'1135'
# /Player1/Piezo1 b'1159'
# /Player1/Piezo1 b'1177'
# /Player1/Piezo1 b'1211'
# /Player1/Piezo1 b'1614'
# /Player1/Piezo1 b'1196'
# /Player1/Piezo1 b'1210'
# /Player1/Piezo1 b'1858'
# /Player1/Piezo1 b'1789'
# /Player1/Piezo1 b'1561'
# /Player1/Piezo1 b'1845'
# /Player1/Piezo1 b'1146'
# /Player1/Piezo1 b'1136'
# /Player1/Piezo1 b'1189'
# /Player1/Piezo1 b'1104'
# /Player1/Piezo1 b'1227'
# /Player1/Piezo1 b'1151'
# /Player1/Piezo1 b'1079'
# /Player1/Piezo1 b'1254'
# /Player1/Piezo1 b'1066'
# /Player1/Piezo1 b'0'
# /Player1/Piezo1 b'0'
# /Player1/Piezo1 b'1171'
# /Player1/Piezo1 b'1438'
# /Player1/Piezo1 b'1712'
# /Player1/Piezo1 b'1876'
# /Player1/Piezo1 b'2042'
# /Player1/Piezo1 b'2201'
# /Player1/Piezo1 b'2224'
# /Player1/Piezo1 b'2291'
# /Player1/Piezo1 b'2448'
# /Player1/Piezo1 b'2450'
# /Player1/Piezo1 b'2570'
# /Player1/Piezo1 b'2635'
# /Player1/Piezo1 b'2738'
# /Player1/Piezo1 b'2754'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 24
#      18 mqttc.connect("192.168.150.81", 1883, 60)
#      20 # Blocking call that processes network traffic, dispatches callbacks and
#      21 # handles reconnecting.
#      22 # Other loop*() functions are available that give a threaded interface and a
#      23 # manual interface.
# ---> 24 mqttc.loop_forever()
#
# File ~/miniforge3/envs/chaos/lib/python3.10/site-packages/paho/mqtt/client.py:2297, in Client.loop_forever(self, timeout, retry_first_connection)
#    2295 rc = MQTTErrorCode.MQTT_ERR_SUCCESS
#    2296 while rc == MQTTErrorCode.MQTT_ERR_SUCCESS:
# -> 2297     rc = self._loop(timeout)
#    2298     # We don't need to worry about locking here, because we've
#    2299     # either called loop_forever() when in single threaded mode, or
#    2300     # in multi threaded mode when loop_stop() has been called and
#    2301     # so no other threads can access _out_packet or _messages.
#    2302     if (self._thread_terminate is True
#    2303         and len(self._out_packet) == 0
#    2304             and len(self._out_messages) == 0):
#
# File ~/miniforge3/envs/chaos/lib/python3.10/site-packages/paho/mqtt/client.py:1663, in Client._loop(self, timeout)
#    1660     rlist = [self._sock, self._sockpairR]
#    1662 try:
# -> 1663     socklist = select.select(rlist, wlist, [], timeout)
#    1664 except TypeError:
#    1665     # Socket isn't correct type, in likelihood connection is lost
#    1666     # ... or we called disconnect(). In that case the socket will
#    (...)
#    1669     # rc != MQTT_ERR_SUCCESS and we don't want state to change from
#    1670     # mqtt_cs_disconnecting.
#    1671     if self._state not in (_ConnectionState.MQTT_CS_DISCONNECTING, _ConnectionState.MQTT_CS_DISCONNECTED):
#
# KeyboardInterrupt:
